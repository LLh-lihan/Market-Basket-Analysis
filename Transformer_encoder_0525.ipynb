# %% [markdown]
# <a href="https://colab.research.google.com/github/LLh-lihan/Market-Basket-Analysis/blob/main/Transformer_encoder_0525.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.2 MB 8.1 MB/s
# ...
#      |████████████████████████████████| 86 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 46.7 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 43.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import TFBertForSequenceClassification, BertTokenizerFast
import tensorflow as tf
from tensorflow.keras.callbacks import *
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('/content/captions.tablechair.csv', on_bad_lines='skip')
data = data.sample(n=1000, random_state=3)

# %% [markdown]
# There is significant difference between the max length of training set and validation set. The max length is set as the max length of the training set

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased', 
max_length = 131, # max length of the text that can go to BERT
pad_to_max_length = True) # pads shorter sequences of text up to the max length)
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/511M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]

# %%
data.dropna(inplace=True)

# %%
X = data['description']

# %%
X_encoded = dict(tokenizer(list(X), add_special_tokens = True, # add [CLS], [SEP]
                                return_attention_mask = True, padding = True))
